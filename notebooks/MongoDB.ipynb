# %%
import pymongo
import pandas as pd

class variables:
    """Placeholder for reused strings in the across the module"""
    USERNAME = 'varshith'
    PASSWORD = 'Jjx0O63qLbueEXQa'

client = pymongo.MongoClient("mongodb+srv://{variables.USERNAME}:{variables.PASSWORD}@project-a-z.auh8afh.mongodb.net/?retryWrites=true&w=majority")

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /home/varshith/project-a/notebooks/MongoDB.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/varshith/project-a/notebooks/MongoDB.ipynb#ch0000007vscode-remote?line=0'>1</a> client.list_database_names()
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1786, in MongoClient.list_database_names(self, session, comment)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1767'>1768</a> def list_database_names(
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1768'>1769</a>     self,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1769'>1770</a>     session: Optional[client_session.ClientSession] = None,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1770'>1771</a>     comment: Optional[Any] = None,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1771'>1772</a> ) -> List[str]:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1772'>1773</a>     """Get a list of the names of all databases on the connected server.
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1773'>1774</a>
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1774'>1775</a>     :Parameters:
#    (...)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1783'>1784</a>     .. versionadded:: 3.6
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1784'>1785</a>     """
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1785'>1786</a>     return [doc["name"] for doc in self.list_databases(session, nameOnly=True, comment=comment)]
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1759, in MongoClient.list_databases(self, session, comment, **kwargs)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1756'>1757</a>     cmd["comment"] = comment
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1757'>1758</a> admin = self._database_default_options("admin")
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1758'>1759</a> res = admin._retryable_read_command(cmd, session=session)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1759'>1760</a> # listDatabases doesn't return a cursor (yet). Fake one.
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1760'>1761</a> cursor = {
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1761'>1762</a>     "id": 0,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1762'>1763</a>     "firstBatch": res["databases"],
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1763'>1764</a>     "ns": "admin.$cmd",
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1764'>1765</a> }
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py:765, in Database._retryable_read_command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=751'>752</a> def _cmd(session, server, sock_info, read_preference):
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=752'>753</a>     return self._command(
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=753'>754</a>         sock_info,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=754'>755</a>         command,
#    (...)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=761'>762</a>         **kwargs,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=762'>763</a>     )
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/database.py?line=764'>765</a> return self.__client._retryable_read(_cmd, read_preference, session)
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1365, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1362'>1363</a> try:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1363'>1364</a>     server = self._select_server(read_pref, session, address=address)
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1364'>1365</a>     with self._socket_from_server(read_pref, server, session) as (sock_info, read_pref):
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1365'>1366</a>         if retrying and not retryable:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1366'>1367</a>             # A retry is not possible because this server does
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1367'>1368</a>             # not support retryable reads, raise the last error.
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1368'>1369</a>             assert last_error is not None
#
# File /usr/lib/python3.8/contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=110'>111</a> del self.args, self.kwds, self.func
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=111'>112</a> try:
# --> <a href='file:///usr/lib/python3.8/contextlib.py?line=112'>113</a>     return next(self.gen)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=113'>114</a> except StopIteration:
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=114'>115</a>     raise RuntimeError("generator didn't yield") from None
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1221, in MongoClient._socket_from_server(self, read_preference, server, session)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1217'>1218</a> topology = self._get_topology()
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1218'>1219</a> single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1220'>1221</a> with self._get_socket(server, session) as sock_info:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1221'>1222</a>     if single:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1222'>1223</a>         if sock_info.is_repl:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1223'>1224</a>             # Use primary preferred to ensure any repl set member
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1224'>1225</a>             # can handle the request.
#
# File /usr/lib/python3.8/contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=110'>111</a> del self.args, self.kwds, self.func
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=111'>112</a> try:
# --> <a href='file:///usr/lib/python3.8/contextlib.py?line=112'>113</a>     return next(self.gen)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=113'>114</a> except StopIteration:
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=114'>115</a>     raise RuntimeError("generator didn't yield") from None
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1156, in MongoClient._get_socket(self, server, session)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1153'>1154</a>     yield session._pinned_connection
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1154'>1155</a>     return
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1155'>1156</a> with server.get_socket(handler=err_handler) as sock_info:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1156'>1157</a>     # Pin this session to the selected server or connection.
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1157'>1158</a>     if in_txn and server.description.server_type in (
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1158'>1159</a>         SERVER_TYPE.Mongos,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1159'>1160</a>         SERVER_TYPE.LoadBalancer,
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1160'>1161</a>     ):
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/mongo_client.py?line=1161'>1162</a>         session._pin(server, sock_info)
#
# File /usr/lib/python3.8/contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=110'>111</a> del self.args, self.kwds, self.func
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=111'>112</a> try:
# --> <a href='file:///usr/lib/python3.8/contextlib.py?line=112'>113</a>     return next(self.gen)
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=113'>114</a> except StopIteration:
#     <a href='file:///usr/lib/python3.8/contextlib.py?line=114'>115</a>     raise RuntimeError("generator didn't yield") from None
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py:1379, in Pool.get_socket(self, handler)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1375'>1376</a> if self.enabled_for_cmap:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1376'>1377</a>     listeners.publish_connection_check_out_started(self.address)
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1378'>1379</a> sock_info = self._get_socket()
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1379'>1380</a> if self.enabled_for_cmap:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1380'>1381</a>     listeners.publish_connection_checked_out(self.address, sock_info.id)
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py:1489, in Pool._get_socket(self)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1486'>1487</a> else:  # We need to create a new connection
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1487'>1488</a>     try:
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1488'>1489</a>         sock_info = self.connect()
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1489'>1490</a>     finally:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1490'>1491</a>         with self._max_connecting_cond:
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py:1350, in Pool.connect(self)
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1346'>1347</a>         sock_info.hello()
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1347'>1348</a>         self.is_writable = sock_info.is_writable
# -> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1349'>1350</a>     sock_info.authenticate()
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1350'>1351</a> except BaseException:
#    <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=1351'>1352</a>     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py:845, in SocketInfo.authenticate(self)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=842'>843</a> creds = self.opts._credentials
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=843'>844</a> if creds:
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=844'>845</a>     auth.authenticate(creds, self)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=845'>846</a> self.ready = True
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=846'>847</a> if self.enabled_for_cmap:
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py:549, in authenticate(credentials, sock_info)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=546'>547</a> mechanism = credentials.mechanism
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=547'>548</a> auth_func = _AUTH_MAP[mechanism]
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=548'>549</a> auth_func(credentials, sock_info)
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py:475, in _authenticate_default(credentials, sock_info)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=472'>473</a>         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-256")
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=473'>474</a>     else:
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=474'>475</a>         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=475'>476</a> else:
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=476'>477</a>     return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py:201, in _authenticate_scram(credentials, sock_info, mechanism)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=198'>199</a> else:
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=199'>200</a>     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=200'>201</a>     res = sock_info.command(source, cmd)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=202'>203</a> server_first = res["payload"]
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/auth.py?line=203'>204</a> parsed = _parse_scram_response(server_first)
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py:743, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=740'>741</a>     self._raise_if_not_writable(unacknowledged)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=741'>742</a> try:
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=742'>743</a>     return command(
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=743'>744</a>         self,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=744'>745</a>         dbname,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=745'>746</a>         spec,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=746'>747</a>         self.is_mongos,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=747'>748</a>         read_preference,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=748'>749</a>         codec_options,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=749'>750</a>         session,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=750'>751</a>         client,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=751'>752</a>         check,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=752'>753</a>         allowable_errors,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=753'>754</a>         self.address,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=754'>755</a>         listeners,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=755'>756</a>         self.max_bson_size,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=756'>757</a>         read_concern,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=757'>758</a>         parse_write_concern_error=parse_write_concern_error,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=758'>759</a>         collation=collation,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=759'>760</a>         compression_ctx=self.compression_context,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=760'>761</a>         use_op_msg=self.op_msg_enabled,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=761'>762</a>         unacknowledged=unacknowledged,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=762'>763</a>         user_fields=user_fields,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=763'>764</a>         exhaust_allowed=exhaust_allowed,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=764'>765</a>     )
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=765'>766</a> except (OperationFailure, NotPrimaryError):
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/pool.py?line=766'>767</a>     raise
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py:160, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=157'>158</a>             client._process_response(response_doc, session)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=158'>159</a>         if check:
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=159'>160</a>             helpers._check_command_response(
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=160'>161</a>                 response_doc,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=161'>162</a>                 sock_info.max_wire_version,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=162'>163</a>                 allowable_errors,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=163'>164</a>                 parse_write_concern_error=parse_write_concern_error,
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=164'>165</a>             )
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=165'>166</a> except Exception as exc:
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/network.py?line=166'>167</a>     if publish:
#
# File ~/project-a/.venv/lib/python3.8/site-packages/pymongo/helpers.py:180, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/helpers.py?line=176'>177</a> elif code == 43:
#     <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/helpers.py?line=177'>178</a>     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> <a href='file:///home/varshith/project-a/.venv/lib/python3.8/site-packages/pymongo/helpers.py?line=179'>180</a> raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}
